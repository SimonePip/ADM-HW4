# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.api.types import is_string_dtype
from pandas.api.types import is_numeric_dtype
from sklearn.decomposition import PCA
from sklearn import preprocessing
import librosa
import scipy.spatial.distance as dist

# %% [markdown]
# # 2.1 Getting your data

# %% [markdown]
# We want to read the datasets to try to understand which key we can use to merge them together.
#
# First of all we want to fill empty values in the datasets.
# The below function take as an input a dataframe and check if in the columns there are any missing values of numeric or string types and fills this value with an empty string, in case of strings, or with a mean of the values of that column in case of numbers.

# %%
def filler(dataframe):
    for col in dataframe.columns:
        if dataframe[col].isnull().any():
            if is_string_dtype(dataframe[col]):
                dataframe[col] = dataframe[col].fillna("")
            elif is_numeric_dtype(dataframe[col]):
                dataframe[col] = dataframe[col].fillna(dataframe[col].mean())

# %% [markdown]
# We take the datasets needed:

# %%
tracks = pd.read_csv("tracks.csv")
echonest = pd.read_csv("echonest.csv")
features = pd.read_csv("features.csv")

# %%
tracks.head()
# Out:
#    track_id  album_comments   album_date_created  album_date_released  \
# 0         2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1         3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2         5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3        10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4        20               0  2008-11-26 01:45:05  2009-01-06 00:00:00
#
#   album_engineer  album_favorites  album_id  \
# 0            NaN                4         1
# 1            NaN                4         1
# 2            NaN                4         1
# 3            NaN                4         6
# 4            NaN                2         4
#
#                            album_information  album_listens album_producer  \
# 0                                    <p></p>           6073            NaN
# 1                                    <p></p>           6073            NaN
# 2                                    <p></p>           6073            NaN
# 3                                        NaN          47632            NaN
# 4  <p> "spiritual songs" from Nicky Cook</p>           2710            NaN
#
#    ... track_information track_interest  track_language_code  \
# 0  ...               NaN           4656                   en
# 1  ...               NaN           1470                   en
# 2  ...               NaN           1933                   en
# 3  ...               NaN          54881                   en
# 4  ...               NaN            978                   en
#
#                                        track_license track_listens  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...          1293
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...           514
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...          1151
# 3  Attribution-NonCommercial-NoDerivatives (aka M...         50135
# 4  Attribution-NonCommercial-NoDerivatives (aka M...           361
#
#   track_lyricist track_number track_publisher  track_tags      track_title
# 0            NaN            3             NaN          []             Food
# 1            NaN            4             NaN          []     Electric Ave
# 2            NaN            6             NaN          []       This World
# 3            NaN            1             NaN          []          Freeway
# 4            NaN            3             NaN          []  Spiritual Level
#
# [5 rows x 53 columns]

# %%
tracks.shape
# Out:
# (106574, 53)

# %%
echonest.head()
# Out:
#    track_id  audio_features_acousticness  audio_features_danceability  \
# 0         2                     0.416675                     0.675894
# 1         3                     0.374408                     0.528643
# 2         5                     0.043567                     0.745566
# 3        10                     0.951670                     0.658179
# 4       134                     0.452217                     0.513238
#
#    audio_features_energy  audio_features_instrumentalness  \
# 0               0.634476                         0.010628
# 1               0.817461                         0.001851
# 2               0.701470                         0.000697
# 3               0.924525                         0.965427
# 4               0.560410                         0.019443
#
#    audio_features_liveness  audio_features_speechiness  audio_features_tempo  \
# 0                 0.177647                    0.159310               165.922
# 1                 0.105880                    0.461818               126.957
# 2                 0.373143                    0.124595               100.260
# 3                 0.115474                    0.032985               111.562
# 4                 0.096567                    0.525519               114.290
#
#    audio_features_valence metadata_album_date  ... temporal_features_214  \
# 0                0.576661                 NaN  ...             -1.992303
# 1                0.269240                 NaN  ...             -1.582331
# 2                0.621661                 NaN  ...             -2.288358
# 3                0.963590          2008-03-11  ...             -3.662988
# 4                0.894072                 NaN  ...             -1.452696
#
#    temporal_features_215 temporal_features_216  temporal_features_217  \
# 0               6.805694              0.233070               0.192880
# 1               8.889308              0.258464               0.220905
# 2              11.527109              0.256821               0.237820
# 3              21.508228              0.283352               0.267070
# 4               2.356398              0.234686               0.199550
#
#   temporal_features_218 temporal_features_219  temporal_features_220  \
# 0              0.027455               0.06408                3.67696
# 1              0.081368               0.06413                6.08277
# 2              0.060122               0.06014                5.92649
# 3              0.125704               0.08082                8.41401
# 4              0.149332               0.06440               11.26707
#
#    temporal_features_221  temporal_features_222  temporal_features_223
# 0                3.61288              13.316690             262.929749
# 1                6.01864              16.673548             325.581085
# 2                5.86635              16.013849             356.755737
# 3                8.33319              21.317064             483.403809
# 4               11.20267              26.454180             751.147705
#
# [5 rows x 250 columns]

# %%
echonest.shape
# Out:
# (13129, 250)

# %%
features.head()
# Out:
#    track_id  chroma_cens_kurtosis_01  chroma_cens_kurtosis_02  \
# 0         2                 7.180653                 5.230309
# 1         3                 1.888963                 0.760539
# 2         5                 0.527563                -0.077654
# 3        10                 3.702245                -0.291193
# 4        20                -0.193837                -0.198527
#
#    chroma_cens_kurtosis_03  chroma_cens_kurtosis_04  chroma_cens_kurtosis_05  \
# 0                 0.249321                 1.347620                 1.482478
# 1                 0.345297                 2.295201                 1.654031
# 2                -0.279610                 0.685883                 1.937570
# 3                 2.196742                -0.234449                 1.367364
# 4                 0.201546                 0.258556                 0.775204
#
#    chroma_cens_kurtosis_06  chroma_cens_kurtosis_07  chroma_cens_kurtosis_08  \
# 0                 0.531371                 1.481593                 2.691455
# 1                 0.067592                 1.366848                 1.054094
# 2                 0.880839                -0.923192                -0.927232
# 3                 0.998411                 1.770694                 1.604566
# 4                 0.084794                -0.289294                -0.816410
#
#    chroma_cens_kurtosis_09  ...  tonnetz_std_04  tonnetz_std_05  \
# 0                 0.866868  ...        0.054125        0.012226
# 1                 0.108103  ...        0.063831        0.014212
# 2                 0.666617  ...        0.040730        0.012691
# 3                 0.521217  ...        0.074358        0.017952
# 4                 0.043851  ...        0.095003        0.022492
#
#    tonnetz_std_06  zcr_kurtosis_01  zcr_max_01  zcr_mean_01  zcr_median_01  \
# 0        0.012111         5.758890    0.459473     0.085629       0.071289
# 1        0.017740         2.824694    0.466309     0.084578       0.063965
# 2        0.014759         6.808415    0.375000     0.053114       0.041504
# 3        0.013921        21.434212    0.452148     0.077515       0.071777
# 4        0.021355        16.669037    0.469727     0.047225       0.040039
#
#    zcr_min_01  zcr_skew_01  zcr_std_01
# 0    0.000000     2.089872    0.061448
# 1    0.000000     1.716724    0.069330
# 2    0.000000     2.193303    0.044861
# 3    0.000000     3.542325    0.040800
# 4    0.000977     3.189831    0.030993
#
# [5 rows x 519 columns]

# %%
features.shape
# Out:
# (106574, 519)

# %% [markdown]
# (note that: features and tracks have the same number of rows)

# %% [markdown]
# We can notice that a common column is **track_id**, so let's check if there are any missing values:

# %%
tracks["track_id"].isnull().any()
# Out:
# False

# %%
echonest["track_id"].isnull().any()
# Out:
# False

# %%
features["track_id"].isnull().any()
# Out:
# False

# %% [markdown]
# Given that there are no missing values in "**track_id**" columns in any dataset, we choose to use it as the key for the merge of the datasets.

# %% [markdown]
# I build a copy and work on it to don't damage the original files.

# %%
tracks_c = tracks.copy()
echonest_c = echonest.copy()
features_c = features.copy()

# %%
# First we are gonna fill the datasets using the function filler()
filler(tracks_c)
filler(echonest_c)
filler(features_c)

# %%
tracks_c.head()
# Out:
#    track_id  album_comments   album_date_created  album_date_released  \
# 0         2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1         3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2         5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3        10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4        20               0  2008-11-26 01:45:05  2009-01-06 00:00:00
#
#   album_engineer  album_favorites  album_id  \
# 0                               4         1
# 1                               4         1
# 2                               4         1
# 3                               4         6
# 4                               2         4
#
#                            album_information  album_listens album_producer  \
# 0                                    <p></p>           6073
# 1                                    <p></p>           6073
# 2                                    <p></p>           6073
# 3                                                     47632
# 4  <p> "spiritual songs" from Nicky Cook</p>           2710
#
#    ... track_information track_interest  track_language_code  \
# 0  ...                             4656                   en
# 1  ...                             1470                   en
# 2  ...                             1933                   en
# 3  ...                            54881                   en
# 4  ...                              978                   en
#
#                                        track_license track_listens  \
# 0  Attribution-NonCommercial-ShareAlike 3.0 Inter...          1293
# 1  Attribution-NonCommercial-ShareAlike 3.0 Inter...           514
# 2  Attribution-NonCommercial-ShareAlike 3.0 Inter...          1151
# 3  Attribution-NonCommercial-NoDerivatives (aka M...         50135
# 4  Attribution-NonCommercial-NoDerivatives (aka M...           361
#
#   track_lyricist track_number track_publisher  track_tags      track_title
# 0                           3                          []             Food
# 1                           4                          []     Electric Ave
# 2                           6                          []       This World
# 3                           1                          []          Freeway
# 4                           3                          []  Spiritual Level
#
# [5 rows x 53 columns]

# %%
tracks_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106574 entries, 0 to 106573
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   track_id                  106574 non-null  int64
#  1   album_comments            106574 non-null  int64
#  2   album_date_created        106574 non-null  object
#  3   album_date_released       106574 non-null  object
#  4   album_engineer            106574 non-null  object
#  5   album_favorites           106574 non-null  int64
#  6   album_id                  106574 non-null  int64
#  7   album_information         106574 non-null  object
#  8   album_listens             106574 non-null  int64
#  9   album_producer            106574 non-null  object
#  10  album_tags                106574 non-null  object
#  11  album_title               106574 non-null  object
#  12  album_tracks              106574 non-null  int64
#  13  album_type                106574 non-null  object
#  14  artist_active_year_begin  106574 non-null  object
#  15  artist_active_year_end    106574 non-null  object
#  16  artist_associated_labels  106574 non-null  object
#  17  artist_bio                106574 non-null  object
#  18  artist_comments           106574 non-null  int64
#  19  artist_date_created       106574 non-null  object
#  20  artist_favorites          106574 non-null  int64
#  21  artist_id                 106574 non-null  int64
#  22  artist_latitude           106574 non-null  float64
#  23  artist_location           106574 non-null  object
#  24  artist_longitude          106574 non-null  float64
#  25  artist_members            106574 non-null  object
#  26  artist_name               106574 non-null  object
#  27  artist_related_projects   106574 non-null  object
#  28  artist_tags               106574 non-null  object
#  29  artist_website            106574 non-null  object
#  30  artist_wikipedia_page     106574 non-null  object
#  31  set_split                 106574 non-null  object
#  32  set_subset                106574 non-null  object
#  33  track_bit_rate            106574 non-null  int64
#  34  track_comments            106574 non-null  int64
#  35  track_composer            106574 non-null  object
#  36  track_date_created        106574 non-null  object
#  37  track_date_recorded       106574 non-null  object
#  38  track_duration            106574 non-null  int64
#  39  track_favorites           106574 non-null  int64
#  40  track_genre_top           106574 non-null  object
#  41  track_genres              106574 non-null  object
#  42  track_genres_all          106574 non-null  object
#  43  track_information         106574 non-null  object
#  44  track_interest            106574 non-null  int64
#  45  track_language_code       106574 non-null  object
#  46  track_license             106574 non-null  object
#  47  track_listens             106574 non-null  int64
#  48  track_lyricist            106574 non-null  object
#  49  track_number              106574 non-null  int64
#  50  track_publisher           106574 non-null  object
#  51  track_tags                106574 non-null  object
#  52  track_title               106574 non-null  object
# dtypes: float64(2), int64(16), object(35)
# memory usage: 43.1+ MB

# %% [markdown]
# We can see that of the 52 total attributes, 35 of them are strings, while the remaining 18 are numbers (float64 or int64)

# %%
echonest_c.head()
# Out:
#    track_id  audio_features_acousticness  audio_features_danceability  \
# 0         2                     0.416675                     0.675894
# 1         3                     0.374408                     0.528643
# 2         5                     0.043567                     0.745566
# 3        10                     0.951670                     0.658179
# 4       134                     0.452217                     0.513238
#
#    audio_features_energy  audio_features_instrumentalness  \
# 0               0.634476                         0.010628
# 1               0.817461                         0.001851
# 2               0.701470                         0.000697
# 3               0.924525                         0.965427
# 4               0.560410                         0.019443
#
#    audio_features_liveness  audio_features_speechiness  audio_features_tempo  \
# 0                 0.177647                    0.159310               165.922
# 1                 0.105880                    0.461818               126.957
# 2                 0.373143                    0.124595               100.260
# 3                 0.115474                    0.032985               111.562
# 4                 0.096567                    0.525519               114.290
#
#    audio_features_valence metadata_album_date  ... temporal_features_214  \
# 0                0.576661                      ...             -1.992303
# 1                0.269240                      ...             -1.582331
# 2                0.621661                      ...             -2.288358
# 3                0.963590          2008-03-11  ...             -3.662988
# 4                0.894072                      ...             -1.452696
#
#    temporal_features_215 temporal_features_216  temporal_features_217  \
# 0               6.805694              0.233070               0.192880
# 1               8.889308              0.258464               0.220905
# 2              11.527109              0.256821               0.237820
# 3              21.508228              0.283352               0.267070
# 4               2.356398              0.234686               0.199550
#
#   temporal_features_218 temporal_features_219  temporal_features_220  \
# 0              0.027455               0.06408                3.67696
# 1              0.081368               0.06413                6.08277
# 2              0.060122               0.06014                5.92649
# 3              0.125704               0.08082                8.41401
# 4              0.149332               0.06440               11.26707
#
#    temporal_features_221  temporal_features_222  temporal_features_223
# 0                3.61288              13.316690             262.929749
# 1                6.01864              16.673548             325.581085
# 2                5.86635              16.013849             356.755737
# 3                8.33319              21.317064             483.403809
# 4               11.20267              26.454180             751.147705
#
# [5 rows x 250 columns]

# %%
echonest_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13129 entries, 0 to 13128
# Columns: 250 entries, track_id to temporal_features_223
# dtypes: float64(244), int64(1), object(5)
# memory usage: 25.0+ MB

# %% [markdown]
# We see, as we did for "tracks", that there are 5 string values over the 250 attributes.

# %%
features_c.head()
# Out:
#    track_id  chroma_cens_kurtosis_01  chroma_cens_kurtosis_02  \
# 0         2                 7.180653                 5.230309
# 1         3                 1.888963                 0.760539
# 2         5                 0.527563                -0.077654
# 3        10                 3.702245                -0.291193
# 4        20                -0.193837                -0.198527
#
#    chroma_cens_kurtosis_03  chroma_cens_kurtosis_04  chroma_cens_kurtosis_05  \
# 0                 0.249321                 1.347620                 1.482478
# 1                 0.345297                 2.295201                 1.654031
# 2                -0.279610                 0.685883                 1.937570
# 3                 2.196742                -0.234449                 1.367364
# 4                 0.201546                 0.258556                 0.775204
#
#    chroma_cens_kurtosis_06  chroma_cens_kurtosis_07  chroma_cens_kurtosis_08  \
# 0                 0.531371                 1.481593                 2.691455
# 1                 0.067592                 1.366848                 1.054094
# 2                 0.880839                -0.923192                -0.927232
# 3                 0.998411                 1.770694                 1.604566
# 4                 0.084794                -0.289294                -0.816410
#
#    chroma_cens_kurtosis_09  ...  tonnetz_std_04  tonnetz_std_05  \
# 0                 0.866868  ...        0.054125        0.012226
# 1                 0.108103  ...        0.063831        0.014212
# 2                 0.666617  ...        0.040730        0.012691
# 3                 0.521217  ...        0.074358        0.017952
# 4                 0.043851  ...        0.095003        0.022492
#
#    tonnetz_std_06  zcr_kurtosis_01  zcr_max_01  zcr_mean_01  zcr_median_01  \
# 0        0.012111         5.758890    0.459473     0.085629       0.071289
# 1        0.017740         2.824694    0.466309     0.084578       0.063965
# 2        0.014759         6.808415    0.375000     0.053114       0.041504
# 3        0.013921        21.434212    0.452148     0.077515       0.071777
# 4        0.021355        16.669037    0.469727     0.047225       0.040039
#
#    zcr_min_01  zcr_skew_01  zcr_std_01
# 0    0.000000     2.089872    0.061448
# 1    0.000000     1.716724    0.069330
# 2    0.000000     2.193303    0.044861
# 3    0.000000     3.542325    0.040800
# 4    0.000977     3.189831    0.030993
#
# [5 rows x 519 columns]

# %%
features_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106574 entries, 0 to 106573
# Columns: 519 entries, track_id to zcr_std_01
# dtypes: float64(518), int64(1)
# memory usage: 422.0 MB

# %% [markdown]
# # Once we have all the datasets, we want to apply PCA before merging them together, so doing we will have dimensionality reduction without loosing too many useful informations

# %% [markdown]
# "features" has no attribute of type string, so they are all numerical.

# %% [markdown]
# Once we got all the datasets well filled, we can start merging them using as key the **track_id** column.

# %%
#final = tracks_c.merge(features_c.merge(echonest_c, on = "track_id"), on = "track_id")
#print(final.shape)
#final.head()
# Out:
# (13129, 820)
#    track_id  album_comments   album_date_created  album_date_released  \
# 0         2               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 1         3               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 2         5               0  2008-11-26 01:44:45  2009-01-05 00:00:00
# 3        10               0  2008-11-26 01:45:08  2008-02-06 00:00:00
# 4       134               0  2008-11-26 01:44:45  2009-01-05 00:00:00
#
#   album_engineer  album_favorites  album_id album_information  album_listens  \
# 0                               4         1           <p></p>           6073
# 1                               4         1           <p></p>           6073
# 2                               4         1           <p></p>           6073
# 3                               4         6                            47632
# 4                               4         1           <p></p>           6073
#
#   album_producer  ... temporal_features_214 temporal_features_215  \
# 0                 ...             -1.992303              6.805694
# 1                 ...             -1.582331              8.889308
# 2                 ...             -2.288358             11.527109
# 3                 ...             -3.662988             21.508228
# 4                 ...             -1.452696              2.356398
#
#    temporal_features_216 temporal_features_217 temporal_features_218  \
# 0               0.233070              0.192880              0.027455
# 1               0.258464              0.220905              0.081368
# 2               0.256821              0.237820              0.060122
# 3               0.283352              0.267070              0.125704
# 4               0.234686              0.199550              0.149332
#
#   temporal_features_219 temporal_features_220 temporal_features_221  \
# 0               0.06408               3.67696               3.61288
# 1               0.06413               6.08277               6.01864
# 2               0.06014               5.92649               5.86635
# 3               0.08082               8.41401               8.33319
# 4               0.06440              11.26707              11.20267
#
#    temporal_features_222 temporal_features_223
# 0              13.316690            262.929749
# 1              16.673548            325.581085
# 2              16.013849            356.755737
# 3              21.317064            483.403809
# 4              26.454180            751.147705
#
# [5 rows x 820 columns]

# %% [markdown]
# As we can see, the number of rows is almost 13k, as demanded.

# %% [markdown]
# ## 2.2 Choose your features (variables)!

# %% [markdown]
# We want to reduce the dimension of the datasets.
# We aim to remove string type attributes given that they can't fit in PCA.
#
# For "tracks" file we want first to see which columns can be useful given that they are plenty of useful information.

# %%
tracks_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106574 entries, 0 to 106573
# Data columns (total 53 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   track_id                  106574 non-null  int64
#  1   album_comments            106574 non-null  int64
#  2   album_date_created        106574 non-null  object
#  3   album_date_released       106574 non-null  object
#  4   album_engineer            106574 non-null  object
#  5   album_favorites           106574 non-null  int64
#  6   album_id                  106574 non-null  int64
#  7   album_information         106574 non-null  object
#  8   album_listens             106574 non-null  int64
#  9   album_producer            106574 non-null  object
#  10  album_tags                106574 non-null  object
#  11  album_title               106574 non-null  object
#  12  album_tracks              106574 non-null  int64
#  13  album_type                106574 non-null  object
#  14  artist_active_year_begin  106574 non-null  object
#  15  artist_active_year_end    106574 non-null  object
#  16  artist_associated_labels  106574 non-null  object
#  17  artist_bio                106574 non-null  object
#  18  artist_comments           106574 non-null  int64
#  19  artist_date_created       106574 non-null  object
#  20  artist_favorites          106574 non-null  int64
#  21  artist_id                 106574 non-null  int64
#  22  artist_latitude           106574 non-null  float64
#  23  artist_location           106574 non-null  object
#  24  artist_longitude          106574 non-null  float64
#  25  artist_members            106574 non-null  object
#  26  artist_name               106574 non-null  object
#  27  artist_related_projects   106574 non-null  object
#  28  artist_tags               106574 non-null  object
#  29  artist_website            106574 non-null  object
#  30  artist_wikipedia_page     106574 non-null  object
#  31  set_split                 106574 non-null  object
#  32  set_subset                106574 non-null  object
#  33  track_bit_rate            106574 non-null  int64
#  34  track_comments            106574 non-null  int64
#  35  track_composer            106574 non-null  object
#  36  track_date_created        106574 non-null  object
#  37  track_date_recorded       106574 non-null  object
#  38  track_duration            106574 non-null  int64
#  39  track_favorites           106574 non-null  int64
#  40  track_genre_top           106574 non-null  object
#  41  track_genres              106574 non-null  object
#  42  track_genres_all          106574 non-null  object
#  43  track_information         106574 non-null  object
#  44  track_interest            106574 non-null  int64
#  45  track_language_code       106574 non-null  object
#  46  track_license             106574 non-null  object
#  47  track_listens             106574 non-null  int64
#  48  track_lyricist            106574 non-null  object
#  49  track_number              106574 non-null  int64
#  50  track_publisher           106574 non-null  object
#  51  track_tags                106574 non-null  object
#  52  track_title               106574 non-null  object
# dtypes: float64(2), int64(16), object(35)
# memory usage: 43.1+ MB

# %% [markdown]
# We decide to keep only useful variables:

# %%
tracks_c = tracks_c[['track_id', 'album_id', 'artist_id', 'track_bit_rate', 
                    'track_duration', 'track_listens']]

# %%
tracks_c.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 106574 entries, 0 to 106573
# Data columns (total 6 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   track_id        106574 non-null  int64
#  1   album_id        106574 non-null  int64
#  2   artist_id       106574 non-null  int64
#  3   track_bit_rate  106574 non-null  int64
#  4   track_duration  106574 non-null  int64
#  5   track_listens   106574 non-null  int64
# dtypes: int64(6)
# memory usage: 4.9 MB

# %% [markdown]
# As we can see, now there are only 3 string values.

# %%
tracks_c
# Out:
#         track_id  album_id  artist_id  track_bit_rate  track_duration  \
# 0              2         1          1          256000             168
# 1              3         1          1          256000             237
# 2              5         1          1          256000             206
# 3             10         6          6          192000             161
# 4             20         4          4          256000             311
# ...          ...       ...        ...             ...             ...
# 106569    155316     22940      24357          320000             162
# 106570    155317     22940      24357          320000             217
# 106571    155318     22940      24357          320000             404
# 106572    155319     22940      24357          320000             146
# 106573    155320     22906      21615          320000             198
#
#         track_listens
# 0                1293
# 1                 514
# 2                1151
# 3               50135
# 4                 361
# ...               ...
# 106569            102
# 106570            165
# 106571            168
# 106572            294
# 106573            705
#
# [106574 rows x 6 columns]

# %% [markdown]
# For the other datasets, we can remove the string values since they don't give us much information.

# %%
echonest_c = echonest_c.select_dtypes(exclude = ['object'])
features_c = features_c.select_dtypes(exclude = ['object'])

# %%
total = tracks_c.merge(features_c.merge(echonest_c, on = 'track_id'), on = 'track_id')

# %%
total.shape
# Out:
# (13129, 768)

# %% [markdown]
# We can see that our dataset is formed by almost 13'000 rows, as demanded.

# %% [markdown]
# ## PCA

# %%
st_sc = preprocessing.StandardScaler()
total_st = pd.DataFrame(st_sc.fit_transform(total[total.columns[1:]].values), columns = total.columns[1:])

# %%
pca = PCA(n_components = 768)
total_pca = pca.fit_transform(total)

print("The variance is:", sum(pca.explained_variance_ratio_))
# Out:
# The variance is: 0.9999999999999998

# %% [markdown]
# ## 2.3 K-Means

# %% [markdown]
# Let's implement, by scratch, our K-Means algorithm:

# %% [markdown]
# We will pass as **Input**:
# - **X**: which stands for the data (dataframe)
# - **k**: the number of clusters
# - **max_iterations**: the max number of allowed iterations before establishing the clusters (set at 100 by default)
#
# We will receive as **Output**:
# - **P**: an array holding the class in which each data point belongs to

# %%
cdist([[1,2,3,4]], [[1,2,3,4]], 'euclidean')
# Out:
# array([[0.]])

# %%
final.shape
# Out:
# (13129, 820)

# %%
len(final)
# Out:
# 13129

# %%
num_cols = [[col for col in final.columns if final[col].dtypes != "O"]]

# %%
def euc_dist(X1, X2):
    return dist.euclidean(X1, X2)

# %%
def init_centroids(data, k):
    # Number of columns in the dataset
    cols = np.shape(data)[1]
    
    # Matrix of 0s to initialize centroids
    centroids = np.mat(np.zeros((k, cols)))
    
    # Picking centroids at random
    for i in range(cols):
        minim = min(data[:, i])
        range_i = float(max(data[:, i] - minim))
        centroids[:, i] = minim + range_i * np.random.rand(k, 1)
    
    # Returning array of random generated centroids
    return centroids

# %%
def kmeans(data, k):
    rows = np.shape(data)[0]
    
    # Hold cluster assignments instance
    cluster_ass = np.mat(np.zeros((rows, 2)))
    
    # Initialize centroids
    centroids = init_centroids(data, k)
    
    # We take the original centroids to check later on
    original_cent = centroids.copy()
    
    changed = True
    num_iter = 0
    
    while changed:
        changed = False
        
        # every row
        for r in range(cols):
            # track minimum distance and the vector's index of the cluster
            min_dist = np.inf
            min_index = -1
            
            # Compute distances
            for j in range(k):
                distance = euc_dist(centroids[j, :], ds[i, :])
                if distance < min_dist:
                    min_dist = distance
                    min_index = j
                
                # Check if cluster assignment of instance has changed
                if cluster_ass[r, 0] != min_index:
                    changed = True
                
                # Assign instance to appropriate cluster
                cluster_ass[r, :] = min_index, min_dist**2
                
                # Update centroid location
            for cent in range(k):
                points = data[np.nonzero(cluster_ass[:, 0].A==cent)[0]]
                centroids[cent, :] = np.mean(points, axis=0)
                    
            # Update the number of iterations
            num_iter += 1
            
        return centroids, cluster_ass, num_iter, original_cent

# %%
kmeans(final, 4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16808/3855415247.py in <module>
# ----> 1 kmeans(final, 4)
#
# ~\AppData\Local\Temp/ipykernel_16808/3635019373.py in kmeans(data, k)
#       6
#       7     # Initialize centroids
# ----> 8     centroids = init_centroids(data, k)
#       9
#      10     # We take the original centroids to check later on
#
# ~\AppData\Local\Temp/ipykernel_16808/2129676368.py in init_centroids(data, k)
#       8     # Picking centroids at random
#       9     for i in range(cols):
# ---> 10         minim = min(data[:, i])
#      11         range_i = float(max(data[:, i] - minim))
#      12         centroids[:, i] = minim + range_i * np.random.rand(k, 1)
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '(slice(None, None, None), 0)' is an invalid key
